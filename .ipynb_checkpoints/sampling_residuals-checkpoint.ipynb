# %%
# basics
import math
import numpy as np
import pandas as pd
import datetime as dt
from datetime import datetime, timedelta
import json
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from scipy import stats

# plotting
import matplotlib.pyplot as plt

# shapefiles
import geopandas as gpd
import shapely

# %% [markdown]
# ## Load rescaled Omicron case numbers

# %%
omicron_cases = pd.read_csv('master_final_re-scaled_cases_20210901_20220228.csv', sep=',').iloc[:,1:]
omicron_cases = omicron_cases[['LTLA_code', 'specimen_date', 'count_mean', 'samples', 'Total_number_of_cases']]
omicron_cases = omicron_cases.rename(columns={
    'LTLA_code': 'origin',
    'specimen_date': 'date'
})

# %%
## aggregate from 2021-11-28 to 2022-01-31
omicron_cases_study = omicron_cases[(omicron_cases.date >= '2021-11-28') & \
                                    (omicron_cases.date <= '2022-01-31')].copy()
omicron_cases_study_agg = omicron_cases_study.groupby('origin').agg({'count_mean': 'sum'}).reset_index()
omicron_cases_study_agg
# Out:
#         origin    count_mean
# 0    E06000001   8600.559874
# 1    E06000002  13015.491082
# 2    E06000003  11984.899771
# 3    E06000004  18898.413039
# 4    E06000005   8705.815612
# ..         ...           ...
# 309  E09000029  19481.282951
# 310  E09000030  29035.634739
# 311  E09000031  24769.120314
# 312  E09000032  33328.888300
# 313  E09000033  16153.541781
#
# [314 rows x 2 columns]

# %% [markdown]
# ## Read in subtree tip <-> LTLA

# %%
BA115_DTA_700_n713_tip_ltla = pd.read_csv('./BA.1.15_DTA_700_n713/tip_ltla_date.tsv', sep='\t')
BA115_DTA_102_n2975_tip_ltla = pd.read_csv('./BA.1.15_DTA_102_n2975/tip_ltla_date.tsv', sep='\t')
BA117_DTA_175_n11351_tip_ltla = pd.read_csv('./BA.1.17_DTA_175_n11351/tip_ltla_date.tsv', sep='\t')
BA11_DTA_1467_n722_tip_ltla = pd.read_csv('./BA.1.1_DTA_1467_n722/tip_ltla_date.tsv', sep='\t')
BA11_DTA_1254_n2249_tip_ltla = pd.read_csv('./BA.1.1_DTA_1254_n2249/tip_ltla_date.tsv', sep='\t')
BA1_DTA_1944_n1406_tip_ltla = pd.read_csv('./BA.1_DTA_1944_n1406/tip_ltla_date.tsv', sep='\t')
BA1_DTA_1800_n944_tip_ltla = pd.read_csv('./BA.1_DTA_1800_n944/tip_ltla_date.tsv', sep='\t')
BA1_DTA_1207_n9727_tip_ltla = pd.read_csv('./BA.1_DTA_1207_n9727/tip_ltla_date.tsv', sep='\t')

# %% [markdown]
# ## Read in LTLA aggregations

# %%
BA115_DTA_700_n713_mergers_rev = pd.read_csv('./BA.1.15_DTA_700_n713/mergers_rev.tsv', sep='\t')
BA115_DTA_102_n2975_mergers_rev = pd.read_csv('./BA.1.15_DTA_102_n2975/mergers_rev.tsv', sep='\t')
BA117_DTA_175_n11351_mergers_rev = pd.read_csv('./BA.1.17_DTA_175_n11351/mergers_rev.tsv', sep='\t')
BA11_DTA_1467_n722_mergers_rev = pd.read_csv('./BA.1.1_DTA_1467_n722/mergers_rev.tsv', sep='\t')
BA11_DTA_1254_n2249_mergers_rev = pd.read_csv('./BA.1.1_DTA_1254_n2249/mergers_rev.tsv', sep='\t')
BA1_DTA_1944_n1406_mergers_rev = pd.read_csv('./BA.1_DTA_1944_n1406/mergers_rev.tsv', sep='\t')
BA1_DTA_1800_n944_mergers_rev = pd.read_csv('./BA.1_DTA_1800_n944/mergers_rev.tsv', sep='\t')
BA1_DTA_1207_n9727_mergers_rev = pd.read_csv('./BA.1_DTA_1207_n9727/mergers_rev.tsv', sep='\t')

# %% [markdown]
# ## Merge LTLAs for BA.1.15_DTA_700_n713

# %% [markdown]
# no mergers needed

# %%
BA115_DTA_700_n713_omicron_cases_study = omicron_cases_study_agg[
    omicron_cases_study_agg.origin.isin(BA115_DTA_700_n713_tip_ltla.ltla.unique().tolist())].copy()
BA115_DTA_700_n713_omicron_cases_study
# Out:
#         origin    count_mean
# 0    E06000001   8600.559874
# 5    E06000006  12103.990620
# 6    E06000007  18042.266297
# 9    E06000010  20271.343420
# 10   E06000011  23676.809516
# ..         ...           ...
# 309  E09000029  19481.282951
# 310  E09000030  29035.634739
# 311  E09000031  24769.120314
# 312  E09000032  33328.888300
# 313  E09000033  16153.541781
#
# [224 rows x 2 columns]

# %%
BA115_DTA_700_n713_omicron_cases_study_sample_n = pd.merge(
    BA115_DTA_700_n713_omicron_cases_study,
    BA115_DTA_700_n713_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA115_DTA_700_n713_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000001   8600.559874         1
# 1    E06000006  12103.990620         1
# 2    E06000007  18042.266297         1
# 3    E06000010  20271.343420         5
# 4    E06000011  23676.809516         6
# ..         ...           ...       ...
# 219  E09000029  19481.282951         6
# 220  E09000030  29035.634739         4
# 221  E09000031  24769.120314         6
# 222  E09000032  33328.888300         7
# 223  E09000033  16153.541781         8
#
# [224 rows x 3 columns]

# %%
plt.scatter(BA115_DTA_700_n713_omicron_cases_study_sample_n.count_mean,
            BA115_DTA_700_n713_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA115_DTA_700_n713_omicron_cases_study_sample_n.count_mean)
BA115_DTA_700_n713_reg = sm.OLS(
    BA115_DTA_700_n713_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA115_DTA_700_n713_reg.summary())
print(BA115_DTA_700_n713_reg.params)
BA115_DTA_700_n713_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     64.20
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           6.33e-14
# Time:                        16:36:44   Log-Likelihood:                -524.12
# No. Observations:                 224   AIC:                             1052.
# Df Residuals:                     222   BIC:                             1059.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2875      0.290      4.433      0.000       0.715       1.860
# ...

# %%
BA115_DTA_700_n713_omicron_cases_study_sample_n['resid'] = BA115_DTA_700_n713_reg.resid
BA115_DTA_700_n713_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n     resid
# 0    E06000001   8600.559874         1 -1.370170
# 1    E06000006  12103.990620         1 -1.811177
# 2    E06000007  18042.266297         1 -2.558677
# 3    E06000010  20271.343420         5  1.160730
# 4    E06000011  23676.809516         6  1.732056
# ..         ...           ...       ...       ...
# 219  E09000029  19481.282951         6  2.260182
# 220  E09000030  29035.634739         4 -0.942504
# 221  E09000031  24769.120314         6  1.594557
# 222  E09000032  33328.888300         7  1.517068
# 223  E09000033  16153.541781         8  4.679072
#
# [224 rows x 4 columns]

# %%
plt.scatter(BA115_DTA_700_n713_omicron_cases_study_sample_n.count_mean,
            BA115_DTA_700_n713_omicron_cases_study_sample_n.resid)

# %%
with open('./BA.1.15_DTA_700_n713/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA115_DTA_700_n713_omicron_cases_study_sample_n.iterrows()]))

# %% [markdown]
# ## Merge LTLAs for BA.1.15_DTA_102_n2975

# %%
BA115_DTA_102_n2975_mergers_rev_dict = dict(zip(BA115_DTA_102_n2975_mergers_rev.child_ltla.values,
                                                BA115_DTA_102_n2975_mergers_rev.parent_ltla.values))
BA115_DTA_102_n2975_omicron_cases_study = omicron_cases_study_agg.copy()
BA115_DTA_102_n2975_omicron_cases_study.origin = BA115_DTA_102_n2975_omicron_cases_study.origin.apply(
    lambda x: BA115_DTA_102_n2975_mergers_rev_dict[x] if x in BA115_DTA_102_n2975_mergers_rev_dict else x
)
BA115_DTA_102_n2975_omicron_cases_study = BA115_DTA_102_n2975_omicron_cases_study.groupby('origin').agg({
    'count_mean': 'sum'
}).reset_index()
BA115_DTA_102_n2975_omicron_cases_study = BA115_DTA_102_n2975_omicron_cases_study[
    BA115_DTA_102_n2975_omicron_cases_study.origin.isin(BA115_DTA_102_n2975_tip_ltla.ltla.unique().tolist())
]
BA115_DTA_102_n2975_omicron_cases_study
# Out:
#         origin    count_mean
# 0    E06000001   8600.559874
# 1    E06000002  13015.491082
# 2    E06000003  11984.899771
# 3    E06000004  18898.413039
# 4    E06000005   8705.815612
# ..         ...           ...
# 261  E09000029  19481.282951
# 262  E09000030  29035.634739
# 263  E09000031  24769.120314
# 264  E09000032  33328.888300
# 265  E09000033  16153.541781
#
# [253 rows x 2 columns]

# %%
BA115_DTA_102_n2975_omicron_cases_study_sample_n = pd.merge(
    BA115_DTA_102_n2975_omicron_cases_study,
    BA115_DTA_102_n2975_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA115_DTA_102_n2975_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000001   8600.559874         3
# 1    E06000002  13015.491082         4
# 2    E06000003  11984.899771         6
# 3    E06000004  18898.413039         4
# 4    E06000005   8705.815612         4
# ..         ...           ...       ...
# 248  E09000029  19481.282951        22
# 249  E09000030  29035.634739        23
# 250  E09000031  24769.120314        30
# 251  E09000032  33328.888300        54
# 252  E09000033  16153.541781        15
#
# [253 rows x 3 columns]

# %%
plt.scatter(BA115_DTA_102_n2975_omicron_cases_study_sample_n.count_mean,
            BA115_DTA_102_n2975_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA115_DTA_102_n2975_omicron_cases_study_sample_n.count_mean)
BA115_DTA_102_n2975_reg = sm.OLS(
    BA115_DTA_102_n2975_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA115_DTA_102_n2975_reg.summary())
print(BA115_DTA_102_n2975_reg.params)
BA115_DTA_102_n2975_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.560
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     319.4
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           1.22e-46
# Time:                        16:36:53   Log-Likelihood:                -817.72
# No. Observations:                 253   AIC:                             1639.
# Df Residuals:                     251   BIC:                             1647.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5757      0.689      2.288      0.023       0.219       2.932
# ...

# %%
BA115_DTA_102_n2975_omicron_cases_study_sample_n['resid'] = BA115_DTA_102_n2975_reg.resid
BA115_DTA_102_n2975_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n      resid
# 0    E06000001   8600.559874         3  -3.853498
# 1    E06000002  13015.491082         4  -5.562735
# 2    E06000003  11984.899771         6  -2.930309
# 3    E06000004  18898.413039         4  -9.172809
# 4    E06000005   8705.815612         4  -2.918088
# ..         ...           ...       ...        ...
# 248  E09000029  19481.282951        22   8.469511
# 249  E09000030  29035.634739        23   3.606451
# 250  E09000031  24769.120314        30  13.224612
# 251  E09000032  33328.888300        54  31.971882
# 252  E09000033  16153.541781        15   3.511590
#
# [253 rows x 4 columns]

# %%
plt.scatter([i for i in range(len(BA115_DTA_102_n2975_reg.resid))], BA115_DTA_102_n2975_reg.resid)

# %%
with open('./BA.1.15_DTA_102_n2975/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA115_DTA_102_n2975_omicron_cases_study_sample_n.iterrows()]))

# %% [markdown]
# ## Merge LTLAs for BA.1.17_DTA_175_n11351

# %%
BA117_DTA_175_n11351_mergers_rev_dict = dict(zip(BA117_DTA_175_n11351_mergers_rev.child_ltla.values,
                                                 BA117_DTA_175_n11351_mergers_rev.parent_ltla.values))
BA117_DTA_175_n11351_omicron_cases_study = omicron_cases_study_agg.copy()
BA117_DTA_175_n11351_omicron_cases_study.origin = BA117_DTA_175_n11351_omicron_cases_study.origin.apply(
    lambda x: BA117_DTA_175_n11351_mergers_rev_dict[x] if x in BA117_DTA_175_n11351_mergers_rev_dict else x
)
BA117_DTA_175_n11351_omicron_cases_study = BA117_DTA_175_n11351_omicron_cases_study.groupby('origin').agg({
    'count_mean': 'sum'
}).reset_index()
BA117_DTA_175_n11351_omicron_cases_study = BA117_DTA_175_n11351_omicron_cases_study[
    BA117_DTA_175_n11351_omicron_cases_study.origin.isin(BA117_DTA_175_n11351_tip_ltla.ltla.unique().tolist())
]
BA117_DTA_175_n11351_omicron_cases_study
# Out:
#         origin    count_mean
# 0    E06000001   8600.559874
# 1    E06000002  13015.491082
# 2    E06000003  11984.899771
# 3    E06000004  18898.413039
# 4    E06000005   8705.815612
# ..         ...           ...
# 249  E09000029  26465.095974
# 250  E09000030  29035.634739
# 251  E09000031  24769.120314
# 252  E09000032  33328.888300
# 253  E09000033  16153.541781
#
# [253 rows x 2 columns]

# %%
BA117_DTA_175_n11351_omicron_cases_study_sample_n = pd.merge(
    BA117_DTA_175_n11351_omicron_cases_study,
    BA117_DTA_175_n11351_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA117_DTA_175_n11351_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000001   8600.559874        17
# 1    E06000002  13015.491082        34
# 2    E06000003  11984.899771        26
# 3    E06000004  18898.413039        48
# 4    E06000005   8705.815612        26
# ..         ...           ...       ...
# 248  E09000029  26465.095974        57
# 249  E09000030  29035.634739        51
# 250  E09000031  24769.120314        51
# 251  E09000032  33328.888300        85
# 252  E09000033  16153.541781        48
#
# [253 rows x 3 columns]

# %%
plt.scatter(BA117_DTA_175_n11351_omicron_cases_study_sample_n.count_mean,
            BA117_DTA_175_n11351_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA117_DTA_175_n11351_omicron_cases_study_sample_n.count_mean)
BA117_DTA_175_n11351_reg = sm.OLS(
    BA117_DTA_175_n11351_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA117_DTA_175_n11351_reg.summary())
print(BA117_DTA_175_n11351_reg.params)
BA117_DTA_175_n11351_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.725
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                     660.9
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           2.88e-72
# Time:                        16:41:06   Log-Likelihood:                -1098.7
# No. Observations:                 253   AIC:                             2201.
# Df Residuals:                     251   BIC:                             2208.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4881      2.120     -0.230      0.818      -4.663       3.686
# ...

# %%
BA117_DTA_175_n11351_omicron_cases_study_sample_n['resid'] = BA117_DTA_175_n11351_reg.resid
BA117_DTA_175_n11351_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n      resid
# 0    E06000001   8600.559874        17  -5.584211
# 1    E06000002  13015.491082        34  -0.427958
# 2    E06000003  11984.899771        26  -5.663235
# 3    E06000004  18898.413039        48  -2.209822
# 4    E06000005   8705.815612        26   3.133424
# ..         ...           ...       ...        ...
# 248  E09000029  26465.095974        57 -13.508639
# 249  E09000030  29035.634739        51 -26.404513
# 250  E09000031  24769.120314        51 -14.958917
# 251  E09000032  33328.888300        85  -3.921841
# 252  E09000033  16153.541781        48   5.153727
#
# [253 rows x 4 columns]

# %%
plt.scatter([i for i in range(len(BA117_DTA_175_n11351_reg.resid))], BA117_DTA_175_n11351_reg.resid)

# %%
with open('./BA.1.17_DTA_175_n11351/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA117_DTA_175_n11351_omicron_cases_study_sample_n.iterrows()]))

# %% [markdown]
# ## Merge LTLAs for BA.1.1_DTA_1467_n722

# %% [markdown]
# no mergers needed

# %%
BA11_DTA_1467_n722_omicron_cases_study = omicron_cases_study_agg[
    omicron_cases_study_agg.origin.isin(BA11_DTA_1467_n722_tip_ltla.ltla.unique().tolist())].copy()
BA11_DTA_1467_n722_omicron_cases_study
# Out:
#         origin    count_mean
# 1    E06000002  13015.491082
# 2    E06000003  11984.899771
# 4    E06000005   8705.815612
# 9    E06000010  20271.343420
# 10   E06000011  23676.809516
# ..         ...           ...
# 309  E09000029  19481.282951
# 310  E09000030  29035.634739
# 311  E09000031  24769.120314
# 312  E09000032  33328.888300
# 313  E09000033  16153.541781
#
# [216 rows x 2 columns]

# %%
BA11_DTA_1467_n722_omicron_cases_study_sample_n = pd.merge(
    BA11_DTA_1467_n722_omicron_cases_study,
    BA11_DTA_1467_n722_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA11_DTA_1467_n722_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000002  13015.491082         2
# 1    E06000003  11984.899771         1
# 2    E06000005   8705.815612         2
# 3    E06000010  20271.343420         2
# 4    E06000011  23676.809516         1
# ..         ...           ...       ...
# 211  E09000029  19481.282951         4
# 212  E09000030  29035.634739         4
# 213  E09000031  24769.120314         7
# 214  E09000032  33328.888300         4
# 215  E09000033  16153.541781         2
#
# [216 rows x 3 columns]

# %%
plt.scatter(BA11_DTA_1467_n722_omicron_cases_study_sample_n.count_mean,
            BA11_DTA_1467_n722_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA11_DTA_1467_n722_omicron_cases_study_sample_n.count_mean)
BA11_DTA_1467_n722_reg = sm.OLS(
    BA11_DTA_1467_n722_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA11_DTA_1467_n722_reg.summary())
print(BA11_DTA_1467_n722_reg.params)
BA11_DTA_1467_n722_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     5.898
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):             0.0160
# Time:                        16:49:45   Log-Likelihood:                -565.69
# No. Observations:                 216   AIC:                             1135.
# Df Residuals:                     214   BIC:                             1142.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5449      0.399      6.374      0.000       1.758       3.332
# ...

# %%
BA11_DTA_1467_n722_omicron_cases_study_sample_n['resid'] = BA11_DTA_1467_n722_reg.resid
BA11_DTA_1467_n722_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n     resid
# 0    E06000002  13015.491082         2 -1.216832
# 1    E06000003  11984.899771         1 -2.163625
# 2    E06000005   8705.815612         2 -0.994333
# 3    E06000010  20271.343420         2 -1.591435
# 4    E06000011  23676.809516         1 -2.767251
# ..         ...           ...       ...       ...
# 211  E09000029  19481.282951         4  0.449354
# 212  E09000030  29035.634739         4 -0.043915
# 213  E09000031  24769.120314         7  3.176355
# 214  E09000032  33328.888300         4 -0.265566
# 215  E09000033  16153.541781         2 -1.378842
#
# [216 rows x 4 columns]

# %%
plt.scatter(BA11_DTA_1467_n722_reg.predict(), BA11_DTA_1467_n722_reg.resid)

# %%
with open('./BA.1.1_DTA_1467_n722/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA11_DTA_1467_n722_omicron_cases_study_sample_n.iterrows()]))

# %% [markdown]
# ## Merge LTLAs for BA.1.1_DTA_1254_n2249

# %%
BA11_DTA_1254_n2249_mergers_rev_dict = dict(zip(BA11_DTA_1254_n2249_mergers_rev.child_ltla.values,
                                                BA11_DTA_1254_n2249_mergers_rev.parent_ltla.values))
BA11_DTA_1254_n2249_omicron_cases_study = omicron_cases_study_agg.copy()
BA11_DTA_1254_n2249_omicron_cases_study.origin = BA11_DTA_1254_n2249_omicron_cases_study.origin.apply(
    lambda x: BA11_DTA_1254_n2249_mergers_rev_dict[x] if x in BA11_DTA_1254_n2249_mergers_rev_dict else x
)
BA11_DTA_1254_n2249_omicron_cases_study = BA11_DTA_1254_n2249_omicron_cases_study.groupby('origin').agg({
    'count_mean': 'sum'
}).reset_index()
BA11_DTA_1254_n2249_omicron_cases_study = BA11_DTA_1254_n2249_omicron_cases_study[
    BA11_DTA_1254_n2249_omicron_cases_study.origin.isin(BA11_DTA_1254_n2249_tip_ltla.ltla.unique().tolist())
]
BA11_DTA_1254_n2249_omicron_cases_study
# Out:
#         origin    count_mean
# 0    E06000001   8600.559874
# 1    E06000002  13015.491082
# 2    E06000003  11984.899771
# 3    E06000004  18898.413039
# 4    E06000005   8705.815612
# ..         ...           ...
# 267  E09000029  19481.282951
# 268  E09000030  29035.634739
# 269  E09000031  24769.120314
# 270  E09000032  33328.888300
# 271  E09000033  16153.541781
#
# [253 rows x 2 columns]

# %%
BA11_DTA_1254_n2249_omicron_cases_study_sample_n = pd.merge(
    BA11_DTA_1254_n2249_omicron_cases_study,
    BA11_DTA_1254_n2249_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA11_DTA_1254_n2249_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000001   8600.559874         4
# 1    E06000002  13015.491082         6
# 2    E06000003  11984.899771         7
# 3    E06000004  18898.413039        10
# 4    E06000005   8705.815612         3
# ..         ...           ...       ...
# 248  E09000029  19481.282951         9
# 249  E09000030  29035.634739         8
# 250  E09000031  24769.120314        10
# 251  E09000032  33328.888300        11
# 252  E09000033  16153.541781         9
#
# [253 rows x 3 columns]

# %%
plt.scatter(BA11_DTA_1254_n2249_omicron_cases_study_sample_n.count_mean,
            BA11_DTA_1254_n2249_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA11_DTA_1254_n2249_omicron_cases_study_sample_n.count_mean)
BA11_DTA_1254_n2249_reg = sm.OLS(
    BA11_DTA_1254_n2249_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA11_DTA_1254_n2249_reg.summary())
print(BA11_DTA_1254_n2249_reg.params)
BA11_DTA_1254_n2249_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     170.9
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           3.87e-30
# Time:                        16:52:53   Log-Likelihood:                -862.31
# No. Observations:                 253   AIC:                             1729.
# Df Residuals:                     251   BIC:                             1736.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3053      0.803      0.380      0.704      -1.275       1.886
# ...

# %%
BA11_DTA_1254_n2249_omicron_cases_study_sample_n['resid'] = BA11_DTA_1254_n2249_reg.resid
BA11_DTA_1254_n2249_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n     resid
# 0    E06000001   8600.559874         4 -0.774764
# 1    E06000002  13015.491082         6 -1.069079
# 2    E06000003  11984.899771         7  0.466490
# 3    E06000004  18898.413039        10 -0.126266
# 4    E06000005   8705.815612         3 -1.829463
# ..         ...           ...       ...       ...
# 248  E09000029  19481.282951         9 -1.429167
# 249  E09000030  29035.634739         8 -7.394293
# 250  E09000031  24769.120314        10 -3.177106
# 251  E09000032  33328.888300        11 -6.625375
# 252  E09000033  16153.541781         9  0.300165
#
# [253 rows x 4 columns]

# %%
plt.scatter(BA11_DTA_1254_n2249_reg.predict(), BA11_DTA_1254_n2249_reg.resid)

# %%
with open('./BA.1.1_DTA_1254_n2249/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA11_DTA_1254_n2249_omicron_cases_study_sample_n.iterrows()]))

# %% [markdown]
# ## Merge LTLAs for BA.1_DTA_1944_n1406

# %%
BA1_DTA_1944_n1406_mergers_rev_dict = dict(zip(BA1_DTA_1944_n1406_mergers_rev.child_ltla.values,
                                               BA1_DTA_1944_n1406_mergers_rev.parent_ltla.values))
BA1_DTA_1944_n1406_omicron_cases_study = omicron_cases_study_agg.copy()
BA1_DTA_1944_n1406_omicron_cases_study.origin = BA1_DTA_1944_n1406_omicron_cases_study.origin.apply(
    lambda x: BA1_DTA_1944_n1406_mergers_rev_dict[x] if x in BA1_DTA_1944_n1406_mergers_rev_dict else x
)
BA1_DTA_1944_n1406_omicron_cases_study = BA1_DTA_1944_n1406_omicron_cases_study.groupby('origin').agg({
    'count_mean': 'sum'
}).reset_index()
BA1_DTA_1944_n1406_omicron_cases_study = BA1_DTA_1944_n1406_omicron_cases_study[
    BA1_DTA_1944_n1406_omicron_cases_study.origin.isin(BA1_DTA_1944_n1406_tip_ltla.ltla.unique().tolist())
]
BA1_DTA_1944_n1406_omicron_cases_study
# Out:
#         origin    count_mean
# 0    E06000001   8600.559874
# 3    E06000004  18898.413039
# 4    E06000005   8705.815612
# 5    E06000006  12103.990620
# 6    E06000007  18042.266297
# ..         ...           ...
# 286  E09000029  19481.282951
# 287  E09000030  29035.634739
# 288  E09000031  24769.120314
# 289  E09000032  33328.888300
# 290  E09000033  16153.541781
#
# [253 rows x 2 columns]

# %%
BA1_DTA_1944_n1406_omicron_cases_study_sample_n = pd.merge(
    BA1_DTA_1944_n1406_omicron_cases_study,
    BA1_DTA_1944_n1406_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA1_DTA_1944_n1406_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000001   8600.559874         2
# 1    E06000004  18898.413039         6
# 2    E06000005   8705.815612         1
# 3    E06000006  12103.990620         3
# 4    E06000007  18042.266297         2
# ..         ...           ...       ...
# 248  E09000029  19481.282951         5
# 249  E09000030  29035.634739        11
# 250  E09000031  24769.120314        11
# 251  E09000032  33328.888300        18
# 252  E09000033  16153.541781        10
#
# [253 rows x 3 columns]

# %%
plt.scatter(BA1_DTA_1944_n1406_omicron_cases_study_sample_n.count_mean,
            BA1_DTA_1944_n1406_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA1_DTA_1944_n1406_omicron_cases_study_sample_n.count_mean)
BA1_DTA_1944_n1406_reg = sm.OLS(
    BA1_DTA_1944_n1406_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA1_DTA_1944_n1406_reg.summary())
print(BA1_DTA_1944_n1406_reg.params)
BA1_DTA_1944_n1406_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.334
# Method:                 Least Squares   F-statistic:                     127.6
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           3.45e-24
# Time:                        16:54:49   Log-Likelihood:                -692.89
# No. Observations:                 253   AIC:                             1390.
# Df Residuals:                     251   BIC:                             1397.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8567      0.404      4.597      0.000       1.061       2.652
# ...

# %%
BA1_DTA_1944_n1406_omicron_cases_study_sample_n['resid'] = BA1_DTA_1944_n1406_reg.resid
BA1_DTA_1944_n1406_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n     resid
# 0    E06000001   8600.559874         2 -1.876761
# 1    E06000004  18898.413039         6 -0.295505
# 2    E06000005   8705.815612         1 -2.901483
# 3    E06000006  12103.990620         3 -1.699641
# 4    E06000007  18042.266297         2 -4.094414
# ..         ...           ...       ...       ...
# 248  E09000029  19481.282951         5 -1.432408
# 249  E09000030  29035.634739        11  2.323481
# 250  E09000031  24769.120314        11  3.325593
# 251  E09000032  33328.888300        18  8.315088
# 252  E09000033  16153.541781        10  4.349207
#
# [253 rows x 4 columns]

# %%
plt.scatter(BA1_DTA_1944_n1406_reg.predict(), BA1_DTA_1944_n1406_reg.resid)

# %%
with open('./BA.1_DTA_1944_n1406/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA1_DTA_1944_n1406_omicron_cases_study_sample_n.iterrows()]))

# %% [markdown]
# ## Merge LTLAs for BA.1_DTA_1800_n944

# %%
BA1_DTA_1800_n944_mergers_rev_dict = dict(zip(BA1_DTA_1800_n944_mergers_rev.child_ltla.values,
                                              BA1_DTA_1800_n944_mergers_rev.parent_ltla.values))
BA1_DTA_1800_n944_omicron_cases_study = omicron_cases_study_agg.copy()
BA1_DTA_1800_n944_omicron_cases_study.origin = BA1_DTA_1800_n944_omicron_cases_study.origin.apply(
    lambda x: BA1_DTA_1800_n944_mergers_rev_dict[x] if x in BA1_DTA_1800_n944_mergers_rev_dict else x
)
BA1_DTA_1800_n944_omicron_cases_study = BA1_DTA_1800_n944_omicron_cases_study.groupby('origin').agg({
    'count_mean': 'sum'
}).reset_index()
BA1_DTA_1800_n944_omicron_cases_study = BA1_DTA_1800_n944_omicron_cases_study[
    BA1_DTA_1800_n944_omicron_cases_study.origin.isin(BA1_DTA_1800_n944_tip_ltla.ltla.unique().tolist())
]
BA1_DTA_1800_n944_omicron_cases_study
# Out:
#         origin    count_mean
# 1    E06000002  13015.491082
# 2    E06000003  11984.899771
# 5    E06000006  12103.990620
# 6    E06000007  18042.266297
# 7    E06000008  13340.028944
# ..         ...           ...
# 306  E09000028  30405.089928
# 308  E09000030  29035.634739
# 309  E09000031  24769.120314
# 310  E09000032  33328.888300
# 311  E09000033  16153.541781
#
# [253 rows x 2 columns]

# %%
BA1_DTA_1800_n944_omicron_cases_study_sample_n = pd.merge(
    BA1_DTA_1800_n944_omicron_cases_study,
    BA1_DTA_1800_n944_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA1_DTA_1800_n944_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000002  13015.491082         1
# 1    E06000003  11984.899771         1
# 2    E06000006  12103.990620         3
# 3    E06000007  18042.266297         4
# 4    E06000008  13340.028944         4
# ..         ...           ...       ...
# 248  E09000028  30405.089928        10
# 249  E09000030  29035.634739         6
# 250  E09000031  24769.120314         1
# 251  E09000032  33328.888300         8
# 252  E09000033  16153.541781         4
#
# [253 rows x 3 columns]

# %%
plt.scatter(BA1_DTA_1800_n944_omicron_cases_study_sample_n.count_mean,
            BA1_DTA_1800_n944_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA1_DTA_1800_n944_omicron_cases_study_sample_n.count_mean)
BA1_DTA_1800_n944_reg = sm.OLS(
    BA1_DTA_1800_n944_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA1_DTA_1800_n944_reg.summary())
print(BA1_DTA_1800_n944_reg.params)
BA1_DTA_1800_n944_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     130.0
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           1.54e-24
# Time:                        16:56:30   Log-Likelihood:                -616.90
# No. Observations:                 253   AIC:                             1238.
# Df Residuals:                     251   BIC:                             1245.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8510      0.307      2.769      0.006       0.246       1.456
# ...

# %%
BA1_DTA_1800_n944_omicron_cases_study_sample_n['resid'] = BA1_DTA_1800_n944_reg.resid
BA1_DTA_1800_n944_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n     resid
# 0    E06000002  13015.491082         1 -2.336003
# 1    E06000003  11984.899771         1 -2.139234
# 2    E06000006  12103.990620         3 -0.161972
# 3    E06000007  18042.266297         4 -0.295757
# 4    E06000008  13340.028944         4  0.602033
# ..         ...           ...       ...       ...
# 248  E09000028  30405.089928        10  3.343832
# 249  E09000030  29035.634739         6 -0.394701
# 250  E09000031  24769.120314         1 -4.580103
# 251  E09000032  33328.888300         8  0.785596
# 252  E09000033  16153.541781         4  0.064854
#
# [253 rows x 4 columns]

# %%
plt.scatter(BA1_DTA_1800_n944_reg.predict(), BA1_DTA_1800_n944_reg.resid)

# %%
with open('./BA.1_DTA_1800_n944/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA1_DTA_1800_n944_omicron_cases_study_sample_n.iterrows()]))

# %% [markdown]
# ## Merge LTLAs for BA.1_DTA_1207_n9727

# %%
BA1_DTA_1207_n9727_mergers_rev_dict = dict(zip(BA1_DTA_1207_n9727_mergers_rev.child_ltla.values,
                                               BA1_DTA_1207_n9727_mergers_rev.parent_ltla.values))
BA1_DTA_1207_n9727_omicron_cases_study = omicron_cases_study_agg.copy()
BA1_DTA_1207_n9727_omicron_cases_study.origin = BA1_DTA_1207_n9727_omicron_cases_study.origin.apply(
    lambda x: BA1_DTA_1207_n9727_mergers_rev_dict[x] if x in BA1_DTA_1207_n9727_mergers_rev_dict else x
)
BA1_DTA_1207_n9727_omicron_cases_study = BA1_DTA_1207_n9727_omicron_cases_study.groupby('origin').agg({
    'count_mean': 'sum'
}).reset_index()
BA1_DTA_1207_n9727_omicron_cases_study = BA1_DTA_1207_n9727_omicron_cases_study[
    BA1_DTA_1207_n9727_omicron_cases_study.origin.isin(BA1_DTA_1207_n9727_tip_ltla.ltla.unique().tolist())
]
BA1_DTA_1207_n9727_omicron_cases_study
# Out:
#         origin    count_mean
# 0    E06000004  43898.803892
# 1    E06000006  12103.990620
# 2    E06000007  18042.266297
# 3    E06000008  36875.014976
# 4    E06000009  11955.959706
# ..         ...           ...
# 249  E09000029  19481.282951
# 250  E09000030  29035.634739
# 251  E09000031  24769.120314
# 252  E09000032  33328.888300
# 253  E09000033  16153.541781
#
# [253 rows x 2 columns]

# %%
BA1_DTA_1207_n9727_omicron_cases_study_sample_n = pd.merge(
    BA1_DTA_1207_n9727_omicron_cases_study,
    BA1_DTA_1207_n9727_tip_ltla.groupby('ltla').count().reset_index().rename(columns={'ltla': 'origin'}),
    on='origin').rename(columns={'name': 'sample_n'})[['origin', 'count_mean', 'sample_n']]
BA1_DTA_1207_n9727_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n
# 0    E06000004  43898.803892        37
# 1    E06000006  12103.990620        24
# 2    E06000007  18042.266297        48
# 3    E06000008  36875.014976        70
# 4    E06000009  11955.959706        16
# ..         ...           ...       ...
# 248  E09000029  19481.282951        36
# 249  E09000030  29035.634739        70
# 250  E09000031  24769.120314        67
# 251  E09000032  33328.888300        97
# 252  E09000033  16153.541781        47
#
# [253 rows x 3 columns]

# %%
plt.scatter(BA1_DTA_1207_n9727_omicron_cases_study_sample_n.count_mean,
            BA1_DTA_1207_n9727_omicron_cases_study_sample_n.sample_n)
plt.show()

# %%
X = sm.add_constant(BA1_DTA_1207_n9727_omicron_cases_study_sample_n.count_mean)
BA1_DTA_1207_n9727_reg = sm.OLS(
    BA1_DTA_1207_n9727_omicron_cases_study_sample_n.sample_n,
    X
).fit()
print(BA1_DTA_1207_n9727_reg.summary())
print(BA1_DTA_1207_n9727_reg.params)
BA1_DTA_1207_n9727_reg.resid
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               sample_n   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     1189.
# Date:                Mon, 01 Aug 2022   Prob (F-statistic):           3.33e-97
# Time:                        16:58:04   Log-Likelihood:                -964.35
# No. Observations:                 253   AIC:                             1933.
# Df Residuals:                     251   BIC:                             1940.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4908      1.203      3.734      0.000       2.122       6.860
# ...

# %%
BA1_DTA_1207_n9727_omicron_cases_study_sample_n['resid'] = BA1_DTA_1207_n9727_reg.resid
BA1_DTA_1207_n9727_omicron_cases_study_sample_n
# Out:
#         origin    count_mean  sample_n      resid
# 0    E06000004  43898.803892        37 -55.660485
# 1    E06000006  12103.990620        24  -4.801355
# 2    E06000007  18042.266297        48   7.271759
# 3    E06000008  36875.014976        70  -8.553371
# 4    E06000009  11955.959706        16 -12.504038
# ..         ...           ...       ...        ...
# 248  E09000029  19481.282951        36  -7.618472
# 249  E09000030  29035.634739        70   7.191838
# 250  E09000031  24769.120314        67  12.761032
# 251  E09000032  33328.888300        97  25.568940
# 252  E09000033  16153.541781        47  10.065218
#
# [253 rows x 4 columns]

# %%
plt.scatter(BA1_DTA_1207_n9727_reg.predict(), BA1_DTA_1207_n9727_reg.resid)

# %%
with open('./BA.1_DTA_1207_n9727/ltla_residual.tsv', 'w+') as outfile:
    outfile.write('ltla\tresidual\n')
    outfile.write('\n'.join(['%s\t%s' % (row.origin, row.resid)
                             for index, row in BA1_DTA_1207_n9727_omicron_cases_study_sample_n.iterrows()]))
